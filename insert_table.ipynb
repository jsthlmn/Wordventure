# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect('vocabulary.db')

# %%
df = pd.read_excel('vocab.xlsx', sheet_name='All', dtype=str)
# print(dt.datetime.now().strftime('%Y-%m-%d %H:%M:%S') + f" Read Data Finished with {df.shape[0]} rows and {df.shape[1]} columns.")

# %%
df.to_sql('vocabulary', conn, if_exists='append', index=False)
